# %% [markdown]
# <a href="https://colab.research.google.com/github/Manant1234/Robs-club-T1-T3-/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
orimg = cv2.imread('/content/Screenshot 2024-08-16 183727.png')

# %%
result = cv2.fastNlMeansDenoisingColored(img, None, 10, 10, 7, 15)

# %%
plt.subplot(122),plt.imshow(orimg)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x78ffebc03f40>)

# %%
plt.subplot(122),plt.imshow(result)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x78ffea7ddff0>)
